# %% [markdown]
# # Extract 8 regions
#
# We're going to extract the 8 regions of interest (ROIs) from the _cis-eQTL_ data.

# %% [markdown]
# ## Load packages
#
# Here we load the necessary packages.

# %%
# Function to check for installation of required packages
def check_install_package(package_name):
    try:
        importlib.import_module(package_name)
    except ImportError:
        print(f'{package_name} is not installed. Install and try again...')
        # subprocess.check_call(['pip', 'install', package_name])

import os
import glob
import importlib
import subprocess
import sys
# argument parsing
import argparse

# get date and time
from datetime import datetime

# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool
# check_install_package('pandas')
import pandas as pd

# pyarrow is supperior to loading parquet files
# check_install_package('pyarrow')
import pyarrow as pa
import pyarrow.parquet as pq

# polars is a fast dataframe library
# check_install_package('polars')
import polars as pl

# for statistical analysis
# check_install_package('scipy')
from scipy import stats
import numpy as np

# scientific colourmaps
# https://www.fabiocrameri.ch/ws/media-library/8c4b111121ff448e843dfef9220bf613/readme_scientificcolourmaps.pdf
# check_install_package('cmcrameri')
import cmcrameri as ccm
from cmcrameri import cm

# for plotting
# check_install_package('matplotlib')
import matplotlib
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

# use Seaborn for visualisations
# check_install_package('seaborn')
import seaborn as sns

# for handling GWAS data
import gwaslab as gl

# %% [markdown]
# We also want some variables set.

# %%
# Create directories for the GWAS data and the reference data
import os
from subprocess import check_output

# set some general defaults
PGC_HITS = "PGC"

POPULATION = "EUR"

# general plotting directory
PLOTS_loc = "PLOTS"

# location to put molQTL results
molQTL_loc = "molQTL_results"

# Check if the directory exists
if not os.path.exists(molQTL_loc):
    # If it doesn't exist, create it
    os.makedirs(molQTL_loc)

# Check if the directory exists
if not os.path.exists(PLOTS_loc):
    # If it doesn't exist, create it
    os.makedirs(PLOTS_loc)

# # regional association plots directory
# REG_PLOTS_loc = PLOTS_loc + "/Regional_Association_Plots"

# # Check if the directory exists
# if not os.path.exists(REG_PLOTS_loc):
#     # If it doesn't exist, create it
#     os.makedirs(REG_PLOTS_loc)

# Reference data directory
REF_loc = "/Users/slaan3/PLINK/references"
print("Checking contents of the reference directory:")
print(check_output(["ls", os.path.join(REF_loc)]).decode("utf8"))

# GWAS data directory
GD_loc = "/Users/slaan3/Library/CloudStorage/GoogleDrive-s.w.vanderlaan@gmail.com/My Drive/Genomics/#Projects/TO_AITION/MR CVD MDD/GWAS"
print("Checking contents of the Google Drive directory:")
print(check_output(["ls", os.path.join(GD_loc)]).decode("utf8"))

# molQTL data directory
NOM_CIS_EQTL_loc = "/Users/slaan3/git/CirculatoryHealth/molqtl/results/version1_aernas1_firstrun/nom_cis_eqtl"
print("Checking contents of the nominal cis-eQTL data directory:")
print(check_output(["ls", os.path.join(NOM_CIS_EQTL_loc)]).decode("utf8"))

PERM_CIS_MQTL_loc = "/Users/slaan3/git/CirculatoryHealth/molqtl/results/perm_cis_mqtl"
print("Checking contents of the permuted cis-mQTL data directory:")
print(check_output(["ls", os.path.join(PERM_CIS_MQTL_loc)]).decode("utf8"))

PERM_TRANS_EQTL_loc = "/Users/slaan3/git/CirculatoryHealth/molqtl/results/version1_aernas1_firstrun/perm_trans_eqtl"
print("Checking contents of the permuted trans-eQTL data directory:")
print(check_output(["ls", os.path.join(PERM_TRANS_EQTL_loc)]).decode("utf8"))

PERM_TRANS_MQTL_loc = (
    "/Users/slaan3/git/CirculatoryHealth/molqtl/results/perm_trans_mqtl"
)
print("Checking contents of the permuted trans-eQTL data directory:")
print(check_output(["ls", os.path.join(PERM_TRANS_MQTL_loc)]).decode("utf8"))
# Out:
# Checking contents of the reference directory:
# 1000G
# GoNL
# HRC_r1_1_2016
# HRCr11_1000Gp3v5
# dbSNP
# refgenie_genomes
# tcga
#
# Checking contents of the Google Drive directory:
# CAC
# CIMT
# GIGASTROKE
# MILLIONHEARTS
# PGC
#
# Checking contents of the nominal cis-eQTL data directory:
# README.md
# tensorqtl_cis_nominal_chr01.cis_qtl_pairs.chr01.parquet
# tensorqtl_cis_nominal_chr02.cis_qtl_pairs.chr02.parquet
# tensorqtl_cis_nominal_chr03.cis_qtl_pairs.chr03.parquet
# tensorqtl_cis_nominal_chr04.cis_qtl_pairs.chr04.parquet
# tensorqtl_cis_nominal_chr05.cis_qtl_pairs.chr05.parquet
# tensorqtl_cis_nominal_chr06.cis_qtl_pairs.chr06.parquet
# tensorqtl_cis_nominal_chr07.cis_qtl_pairs.chr07.parquet
# tensorqtl_cis_nominal_chr08.cis_qtl_pairs.chr08.parquet
# tensorqtl_cis_nominal_chr09.cis_qtl_pairs.chr09.parquet
# tensorqtl_cis_nominal_chr10.cis_qtl_pairs.chr10.parquet
# tensorqtl_cis_nominal_chr11.cis_qtl_pairs.chr11.parquet
# tensorqtl_cis_nominal_chr12.cis_qtl_pairs.chr12.parquet
# tensorqtl_cis_nominal_chr13.cis_qtl_pairs.chr13.parquet
# tensorqtl_cis_nominal_chr14.cis_qtl_pairs.chr14.parquet
# tensorqtl_cis_nominal_chr15.cis_qtl_pairs.chr15.parquet
# tensorqtl_cis_nominal_chr16.cis_qtl_pairs.chr16.parquet
# tensorqtl_cis_nominal_chr17.cis_qtl_pairs.chr17.parquet
# tensorqtl_cis_nominal_chr18.cis_qtl_pairs.chr18.parquet
# tensorqtl_cis_nominal_chr19.cis_qtl_pairs.chr19.parquet
# tensorqtl_cis_nominal_chr20.cis_qtl_pairs.chr20.parquet
# tensorqtl_cis_nominal_chr21.cis_qtl_pairs.chr21.parquet
# tensorqtl_cis_nominal_chr22.cis_qtl_pairs.chr22.parquet
# tensorqtl_nominal_cis_qtl_pairs.annot.parquet
# tensorqtl_nominal_cis_qtl_pairs.sumstats.gwaslab
# tensorqtl_nominal_cis_qtl_pairs.sumstats.log
# tensorqtl_nominal_cis_qtl_pairs.sumstats.parquet
# tensorqtl_nominal_cis_qtl_pairs.sumstats.top.csv
# tensorqtl_nominal_cis_qtl_pairs.sumstats.top.xlsx
#
# Checking contents of the permuted cis-mQTL data directory:
# README.md
# tensormqtl.perm_cis_mqtl.txt
# tensormqtl_cis_chr1.cis_qtl.txt.gz
# tensormqtl_cis_chr10.cis_qtl.txt.gz
# tensormqtl_cis_chr11.cis_qtl.txt.gz
# tensormqtl_cis_chr12.cis_qtl.txt.gz
# tensormqtl_cis_chr13.cis_qtl.txt.gz
# tensormqtl_cis_chr14.cis_qtl.txt.gz
# tensormqtl_cis_chr15.cis_qtl.txt.gz
# tensormqtl_cis_chr16.cis_qtl.txt.gz
# tensormqtl_cis_chr17.cis_qtl.txt.gz
# tensormqtl_cis_chr18.cis_qtl.txt.gz
# tensormqtl_cis_chr19.cis_qtl.txt.gz
# tensormqtl_cis_chr2.cis_qtl.txt.gz
# tensormqtl_cis_chr20.cis_qtl.txt.gz
# tensormqtl_cis_chr21.cis_qtl.txt.gz
# tensormqtl_cis_chr22.cis_qtl.txt.gz
# tensormqtl_cis_chr3.cis_qtl.txt.gz
# tensormqtl_cis_chr4.cis_qtl.txt.gz
# tensormqtl_cis_chr5.cis_qtl.txt.gz
# tensormqtl_cis_chr6.cis_qtl.txt.gz
# tensormqtl_cis_chr7.cis_qtl.txt.gz
# tensormqtl_cis_chr8.cis_qtl.txt.gz
# tensormqtl_cis_chr9.cis_qtl.txt.gz
#
# Checking contents of the permuted trans-eQTL data directory:
# README.md
# tensorqtl_trans_full.trans_qtl_pairs.parquet
#
# Checking contents of the permuted trans-eQTL data directory:
# README.md
# tensormqtl_perm_trans_qtl_pairs.annot.parquet
# tensormqtl_trans_chr1.trans_qtl_pairs.parquet
# tensormqtl_trans_chr10.trans_qtl_pairs.parquet
# tensormqtl_trans_chr11.trans_qtl_pairs.parquet
# tensormqtl_trans_chr12.trans_qtl_pairs.parquet
# tensormqtl_trans_chr13.trans_qtl_pairs.parquet
# tensormqtl_trans_chr14.trans_qtl_pairs.parquet
# tensormqtl_trans_chr15.trans_qtl_pairs.parquet
# tensormqtl_trans_chr16.trans_qtl_pairs.parquet
# tensormqtl_trans_chr17.trans_qtl_pairs.parquet
# tensormqtl_trans_chr18.trans_qtl_pairs.parquet
# tensormqtl_trans_chr19.trans_qtl_pairs.parquet
# tensormqtl_trans_chr2.trans_qtl_pairs.parquet
# tensormqtl_trans_chr20.trans_qtl_pairs.parquet
# tensormqtl_trans_chr21.trans_qtl_pairs.parquet
# tensormqtl_trans_chr22.trans_qtl_pairs.parquet
# tensormqtl_trans_chr3.trans_qtl_pairs.parquet
# tensormqtl_trans_chr4.trans_qtl_pairs.parquet
# tensormqtl_trans_chr5.trans_qtl_pairs.parquet
# tensormqtl_trans_chr6.trans_qtl_pairs.parquet
# tensormqtl_trans_chr7.trans_qtl_pairs.parquet
# tensormqtl_trans_chr8.trans_qtl_pairs.parquet
# tensormqtl_trans_chr9.trans_qtl_pairs.parquet

# %% [markdown]
# ## Load data
#
# We are going to need the list of ROIs and the annotated cis-eQTL data.

# %% [markdown]
# ### Regions-of-interest
#
# Let's load the 8 regions we are interested in.

# %%
# polars.read_excel(
# source: str | BytesIO | Path | BinaryIO | bytes,
# *,
# sheet_id: None = None,
# sheet_name: str,
# engine: Literal['xlsx2csv', 'openpyxl', 'pyxlsb'] | None = None,
# xlsx2csv_options: dict[str, Any] | None = None,
# read_csv_options: dict[str, Any] | None = None,
# schema_overrides: SchemaDict | None = None,
# raise_if_empty: bool = True,
# )

target_regions = pl.read_csv(
    source=os.path.join("targets/regions.csv")
)

# %%
target_regions
# Out:
# shape: (8, 4)
# ┌─────────────┬────────────┬────────────────┬────────────────┐
# │ leadSNP     ┆ chromosome ┆ lower_position ┆ upper_position │
# │ ---         ┆ ---        ┆ ---            ┆ ---            │
# │ str         ┆ i64        ┆ i64            ┆ i64            │
# ╞═════════════╪════════════╪════════════════╪════════════════╡
# │ 7:12263538  ┆ 7          ┆ 11263538       ┆ 13263538       │
# │ 19:4044579  ┆ 19         ┆ 3044579        ┆ 5044579        │
# │ 15:38843887 ┆ 15         ┆ 37843887       ┆ 39843887       │
# │ 7:114059156 ┆ 7          ┆ 113059156      ┆ 115059156      │
# │ 7:2760750   ┆ 7          ┆ 1760750        ┆ 3760750        │
# │ 7:1937261   ┆ 7          ┆ 937261         ┆ 2937261        │
# │ 2:165045101 ┆ 2          ┆ 164045101      ┆ 166045101      │
# │ 2:164915279 ┆ 2          ┆ 163915279      ┆ 165915279      │
# └─────────────┴────────────┴────────────────┴────────────────┘

# %% [markdown]
# ### cis-eQTL data
#
# We previously parsed the cis-eQTL data into a `.parquet` file which includes annotated results. For details check `` in the `` GitHub repository.
#
# Here we'll simply load thed annotated data.

# %%
# read in data
# https://stackoverflow.com/questions/33813815/how-to-read-a-parquet-file-into-pandas-dataframe

import polars as pl

# annotated cis-eQTLs
sumstats_nom_cis_eqtl = pl.read_parquet(
    source=os.path.join(
        NOM_CIS_EQTL_loc, "tensorqtl_nominal_cis_qtl_pairs.annot.parquet"
    )
)

# %%
sumstats_nom_cis_eqtl
# Out:
# shape: (77_285_276, 25)
# ┌────────────┬────────────┬────────────┬──────────┬───┬────────┬───────────┬────────────┬──────────┐
# │ EnsemblID  ┆ VariantID  ┆ tss_distan ┆ CAF_eQTL ┆ … ┆ TotalN ┆ MAF       ┆ MissingDat ┆ HWE_P    │
# │ ---        ┆ ---        ┆ ce         ┆ ---      ┆   ┆ ---    ┆ ---       ┆ aProportio ┆ ---      │
# │ str        ┆ str        ┆ ---        ┆ f32      ┆   ┆ i64    ┆ f64       ┆ n          ┆ f64      │
# │            ┆            ┆ i32        ┆          ┆   ┆        ┆           ┆ ---        ┆          │
# │            ┆            ┆            ┆          ┆   ┆        ┆           ┆ f64        ┆          │
# ╞════════════╪════════════╪════════════╪══════════╪═══╪════════╪═══════════╪════════════╪══════════╡
# │ ENSG000001 ┆ 1:693731   ┆ -240519    ┆ 0.134185 ┆ … ┆ 2124   ┆ 0.122957  ┆ 0.000075   ┆ 0.544841 │
# │ 87634      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 1:714596   ┆ -219654    ┆ 0.038339 ┆ … ┆ 2124   ┆ 0.0322165 ┆ 0.000024   ┆ 0.272504 │
# │ 87634      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 1:715367   ┆ -218883    ┆ 0.038339 ┆ … ┆ 2124   ┆ 0.0347528 ┆ 0.000019   ┆ 0.176551 │
# │ 87634      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 1:717485   ┆ -216765    ┆ 0.038339 ┆ … ┆ 2124   ┆ 0.0343883 ┆ 0.000022   ┆ 0.174817 │
# │ 87634      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 1:720381   ┆ -213869    ┆ 0.038339 ┆ … ┆ 2124   ┆ 0.0355205 ┆ 0.00002    ┆ 0.110452 │
# │ 87634      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ …          ┆ …          ┆ …          ┆ …        ┆ … ┆ …      ┆ …         ┆ …          ┆ …        │
# │ ENSG000000 ┆ 22:5122024 ┆ 444664     ┆ 0.035942 ┆ … ┆ 2124   ┆ 0.0715553 ┆ 0.000034   ┆ 0.622809 │
# │ 79974      ┆ 9          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000000 ┆ 22:5122119 ┆ 445605     ┆ 0.035144 ┆ … ┆ 2124   ┆ 0.0516673 ┆ 0.000015   ┆ 0.500544 │
# │ 79974      ┆ 0          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000000 ┆ 22:5122173 ┆ 446146     ┆ 0.035942 ┆ … ┆ 2124   ┆ 0.0732185 ┆ 0.000016   ┆ 0.523538 │
# │ 79974      ┆ 1          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000000 ┆ 22:5122210 ┆ 446515     ┆ 0.054313 ┆ … ┆ 2124   ┆ 0.0514234 ┆ 0.000033   ┆ 0.821168 │
# │ 79974      ┆ 0          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000000 ┆ 22:5122980 ┆ 454220     ┆ 0.038339 ┆ … ┆ 2124   ┆ 0.0748171 ┆ 0.000012   ┆ 0.342973 │
# │ 79974      ┆ 5          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# └────────────┴────────────┴────────────┴──────────┴───┴────────┴───────────┴────────────┴──────────┘

# %% [markdown]
# ## Extract data
#
# Now we're ready to extract the data for each region in one table.

# %%
import polars as pl

# Initialize an empty DataFrame to store the filtered results
filtered_results = pl.DataFrame()

# Loop through each row of df2 and filter df1 based on chromosome and position range
for row in target_regions.iter_rows(named=True):
    chrom = row['chromosome']
    lower_pos = row['lower_position']
    upper_pos = row['upper_position']
    
    # Filter df1 based on the chromosome and position range using polars
    filtered = sumstats_nom_cis_eqtl.filter(
        (sumstats_nom_cis_eqtl['chromosome'] == chrom) & 
        (sumstats_nom_cis_eqtl['position'] >= lower_pos) & 
        (sumstats_nom_cis_eqtl['position'] <= upper_pos)
    )
    
    # Append the filtered rows to the result DataFrame
    filtered_results = filtered_results.vstack(filtered)

# Show the final filtered DataFrame
print(filtered_results)
# Out:
# shape: (621_506, 25)
# ┌────────────┬────────────┬────────────┬──────────┬───┬────────┬───────────┬────────────┬──────────┐
# │ EnsemblID  ┆ VariantID  ┆ tss_distan ┆ CAF_eQTL ┆ … ┆ TotalN ┆ MAF       ┆ MissingDat ┆ HWE_P    │
# │ ---        ┆ ---        ┆ ce         ┆ ---      ┆   ┆ ---    ┆ ---       ┆ aProportio ┆ ---      │
# │ str        ┆ str        ┆ ---        ┆ f32      ┆   ┆ i64    ┆ f64       ┆ n          ┆ f64      │
# │            ┆            ┆ i32        ┆          ┆   ┆        ┆           ┆ ---        ┆          │
# │            ┆            ┆            ┆          ┆   ┆        ┆           ┆ f64        ┆          │
# ╞════════════╪════════════╪════════════╪══════════╪═══╪════════╪═══════════╪════════════╪══════════╡
# │ ENSG000001 ┆ 7:11263538 ┆ 327489     ┆ 0.071086 ┆ … ┆ 2124   ┆ 0.0684027 ┆ 0.000001   ┆ 0.610073 │
# │ 89043      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 7:11264536 ┆ 328487     ┆ 0.047923 ┆ … ┆ 2124   ┆ 0.0536334 ┆ 0.000004   ┆ 0.830364 │
# │ 89043      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 7:11264670 ┆ 328621     ┆ 0.075879 ┆ … ┆ 2124   ┆ 0.0805431 ┆ 0.000006   ┆ 0.304873 │
# │ 89043      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 7:11264692 ┆ 328643     ┆ 0.521565 ┆ … ┆ 2124   ┆ 0.45498   ┆ 0.000005   ┆ 1.0      │
# │ 89043      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 7:11265421 ┆ 329372     ┆ 0.598243 ┆ … ┆ 2124   ┆ 0.38279   ┆ 0.000004   ┆ 0.408573 │
# │ 89043      ┆            ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ …          ┆ …          ┆ …          ┆ …        ┆ … ┆ …      ┆ …         ┆ …          ┆ …        │
# │ ENSG000001 ┆ 2:16591356 ┆ -593964    ┆ 0.646965 ┆ … ┆ 2124   ┆ 0.350612  ┆ 0.000003   ┆ 0.390789 │
# │ 36546      ┆ 4          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 2:16591424 ┆ -593287    ┆ 0.162939 ┆ … ┆ 2124   ┆ 0.17201   ┆ 0.000009   ┆ 0.322517 │
# │ 36546      ┆ 1          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 2:16591435 ┆ -593175    ┆ 0.227636 ┆ … ┆ 2124   ┆ 0.226552  ┆ 0.000008   ┆ 0.292141 │
# │ 36546      ┆ 3          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 2:16591441 ┆ -593112    ┆ 0.234026 ┆ … ┆ 2124   ┆ 0.234516  ┆ 0.000008   ┆ 0.671834 │
# │ 36546      ┆ 6          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# │ ENSG000001 ┆ 2:16591480 ┆ -592726    ┆ 0.13738  ┆ … ┆ 2124   ┆ 0.137259  ┆ 0.000004   ┆ 0.141703 │
# │ 36546      ┆ 2          ┆            ┆          ┆   ┆        ┆           ┆            ┆          │
# └────────────┴────────────┴────────────┴──────────┴───┴────────┴───────────┴────────────┴──────────┘

# %%
# Count the number of rows in the filtered_results DataFrame
num_rows = filtered_results.shape[0]

# Print the number of rows
print(f"Number of rows in filtered_results: {num_rows}")
# Out:
# Number of rows in filtered_results: 621506

# %%
del sumstats_perm_trans_mqtl

# %% [markdown]
# ## Annotation
#
# Let's also annotate this table with more information.

# %%
import mygene
import pandas as pd
import polars as pl

# Initialize mygene client
mg = mygene.MyGeneInfo()

# Convert the polars DataFrame (filtered_results) to a pandas DataFrame
filtered_results_pd = filtered_results.to_pandas()

# Get the unique Ensembl IDs from the polars DataFrame (filtered_results)
ensembl_ids = filtered_results['EnsemblID'].unique().to_list()

# Query mygene to get additional gene information (e.g., symbol, name, etc.)
gene_info = mg.querymany(ensembl_ids, 
                         scopes='ensembl.gene', 
                         fields='symbol,name,alias,type_of_gene,map_location,genomic_pos,entrezgene,HGNC,summary', 
                         species='human')

# Convert the gene info to a pandas DataFrame
gene_info_df = pd.DataFrame(gene_info)

# Select relevant columns
gene_info_df = gene_info_df[['query', 'symbol', 'name', 'alias', 'type_of_gene', 'map_location', 'genomic_pos', 'entrezgene', 'HGNC', 'summary']]

# Convert the pandas DataFrame back to polars DataFrame
gene_info_df
# Out:
# INFO:biothings.client:querying 1-176...
# INFO:biothings.client:done.
# INFO:biothings.client:Finished.
#                query   symbol  \
# 0    ENSG00000140320    BAHD1
# 1    ENSG00000064961   HMG20B
# 2    ENSG00000065717     TLE2
# 3    ENSG00000146802  TMEM168
# 4    ENSG00000073067   CYP2W1
# ..               ...      ...
# 171  ENSG00000166068   SPRED1
# 172  ENSG00000130255    RPL36
# 173  ENSG00000105229    PIAS4
# 174  ENSG00000128891   CCDC32
# 175  ENSG00000176619    LMNB2
#
#                                                  name  \
# 0         bromo adjacent homology domain containing 1
# 1                             high mobility group 20B
# 2    TLE family member 2, transcriptional corepressor
# 3                           transmembrane protein 168
# 4       cytochrome P450 family 2 subfamily W member 1
# ..                                                ...
# 171          sprouty related EVH1 domain containing 1
# 172                             ribosomal protein L36
# 173             protein inhibitor of activated STAT 4
# 174                  coiled-coil domain containing 32
# 175                                          lamin B2
#
#                                                  alias    type_of_gene  \
# 0                                                  NaN  protein-coding
# 1    [BRAF25, BRAF35, HMGX2, HMGXB2, PP7706, SMARCE...  protein-coding
# 2                                    [ESG, ESG2, GRG2]  protein-coding
# 3                                                  NaN  protein-coding
# 4                                                  NaN  protein-coding
# ..                                                 ...             ...
# 171           [LGSS, NFLS, PPP1R147, hSpred1, spred-1]  protein-coding
# 172                                        [L36, eL36]  protein-coding
# 173                  [PIAS-gamma, PIASY, Piasg, ZMIZ6]  protein-coding
# 174                                  [C15orf57, CFNDS]  protein-coding
# 175                        [EPM9, LAMB2, LMN2, MCPH27]  protein-coding
#
#     map_location                                        genomic_pos  \
# 0        15q15.1  {'chr': '15', 'end': 40468236, 'ensemblgene': ...
# 1        19p13.3  {'chr': '19', 'end': 3579088, 'ensemblgene': '...
# 2        19p13.3  {'chr': '19', 'end': 3047635, 'ensemblgene': '...
# 3         7q31.1  {'chr': '7', 'end': 112790423, 'ensemblgene': ...
# 4         7p22.3  {'chr': '7', 'end': 989640, 'ensemblgene': 'EN...
# ..           ...                                                ...
# 171        15q14  {'chr': '15', 'end': 38357249, 'ensemblgene': ...
# 172      19p13.3  {'chr': '19', 'end': 5691875, 'ensemblgene': '...
# 173      19p13.3  {'chr': '19', 'end': 4039386, 'ensemblgene': '...
# 174      15q15.1  {'chr': '15', 'end': 40565054, 'ensemblgene': ...
# 175      19p13.3  {'chr': '19', 'end': 2456959, 'ensemblgene': '...
#
#     entrezgene   HGNC                                            summary
# 0        22893  29153  Enables chromatin binding activity. Involved i...
# 1        10362   5002  Predicted to enable DNA binding activity. Pred...
# 2         7089  11838  Enables transcription corepressor activity. In...
# 3        64418  25826  Located in transport vesicle. [provided by All...
# 4        54905  20243  This gene encodes a member of the cytochrome P...
# ..         ...    ...                                                ...
# 171     161742  20249  The protein encoded by this gene is a member o...
# 172      25873  13631  Ribosomes, the organelles that catalyze protei...
# 173      51588  17002  Enables SUMO ligase activity and ubiquitin pro...
# 174      90416  28295  Involved in head development. [provided by All...
# 175      84823   6638  This gene encodes a B type nuclear lamin. The ...
#
# [176 rows x 10 columns]

# %%
# Merge the original pandas DataFrame (filtered_results_pd) with the gene information DataFrame on 'EnsemblID'
filtered_results_annotated = filtered_results_pd.merge(gene_info_df, left_on='EnsemblID', right_on='query', how='left')

# Drop the 'query' column (since it's the same as 'EnsemblID')
filtered_results_annotated.drop(columns=['query'], inplace=True)

# Display the annotated DataFrame
print(filtered_results_annotated)
# Out:
#               EnsemblID    VariantID  tss_distance  CAF_eQTL  ma_samples  \
# 0       ENSG00000189043   7:11263538        327489  0.071086          84
# 1       ENSG00000189043   7:11264536        328487  0.047923          56
# 2       ENSG00000189043   7:11264670        328621  0.075879          88
# 3       ENSG00000189043   7:11264692        328643  0.521565         455
# 4       ENSG00000189043   7:11265421        329372  0.598243         404
# ...                 ...          ...           ...       ...         ...
# 621501  ENSG00000136546  2:165913564       -593964  0.646965         362
# 621502  ENSG00000136546  2:165914241       -593287  0.162939         186
# 621503  ENSG00000136546  2:165914353       -593175  0.227636         251
# 621504  ENSG00000136546  2:165914416       -593112  0.234026         259
# 621505  ENSG00000136546  2:165914802       -592726  0.137380         155
#
#         ma_count  pval_nominal      Beta        SE  chromosome  ...     HWE_P  \
# 0             89      0.337176 -0.027423  0.028549           7  ...  0.610073
# 1             60      0.349662  0.032065  0.034257           7  ...  0.830364
# 2             95      0.299686 -0.028301  0.027264           7  ...  0.304873
# 3            599      0.789388 -0.004011  0.015009           7  ...  1.000000
# 4            503      0.354785 -0.014423  0.015574           7  ...  0.408573
# ...          ...           ...       ...       ...         ...  ...       ...
# 621501       442      0.026601  0.039790  0.017899           2  ...  0.390789
# 621502       204      0.591413 -0.012557  0.023379           2  ...  0.322517
# 621503       285      0.338273  0.019565  0.020414           2  ...  0.292141
# 621504       293      0.031736  0.043972  0.020424           2  ...  0.671834
# 621505       172      0.873595 -0.003890  0.024438           2  ...  0.141703
#
#         symbol                                          name  \
# 0       NDUFA4       NDUFA4 mitochondrial complex associated
# 1       NDUFA4       NDUFA4 mitochondrial complex associated
# 2       NDUFA4       NDUFA4 mitochondrial complex associated
# 3       NDUFA4       NDUFA4 mitochondrial complex associated
# 4       NDUFA4       NDUFA4 mitochondrial complex associated
# ...        ...                                           ...
# 621501   SCN7A  sodium voltage-gated channel alpha subunit 7
# 621502   SCN7A  sodium voltage-gated channel alpha subunit 7
# 621503   SCN7A  sodium voltage-gated channel alpha subunit 7
# 621504   SCN7A  sodium voltage-gated channel alpha subunit 7
# 621505   SCN7A  sodium voltage-gated channel alpha subunit 7
#
#                                                     alias    type_of_gene  \
# 0       [CI-9k, CI-MLRQ, COXFA4, MC4DN21, MISTR1, MLRQ...  protein-coding
# 1       [CI-9k, CI-MLRQ, COXFA4, MC4DN21, MISTR1, MLRQ...  protein-coding
# 2       [CI-9k, CI-MLRQ, COXFA4, MC4DN21, MISTR1, MLRQ...  protein-coding
# 3       [CI-9k, CI-MLRQ, COXFA4, MC4DN21, MISTR1, MLRQ...  protein-coding
# 4       [CI-9k, CI-MLRQ, COXFA4, MC4DN21, MISTR1, MLRQ...  protein-coding
# ...                                                   ...             ...
# 621501                       [NaG, Nav2.1, Nav2.2, SCN6A]  protein-coding
# 621502                       [NaG, Nav2.1, Nav2.2, SCN6A]  protein-coding
# 621503                       [NaG, Nav2.1, Nav2.2, SCN6A]  protein-coding
# 621504                       [NaG, Nav2.1, Nav2.2, SCN6A]  protein-coding
# 621505                       [NaG, Nav2.1, Nav2.2, SCN6A]  protein-coding
#
#        map_location                                        genomic_pos  \
# 0            7p21.3  {'chr': '7', 'end': 10940153, 'ensemblgene': '...
# 1            7p21.3  {'chr': '7', 'end': 10940153, 'ensemblgene': '...
# 2            7p21.3  {'chr': '7', 'end': 10940153, 'ensemblgene': '...
# 3            7p21.3  {'chr': '7', 'end': 10940153, 'ensemblgene': '...
# 4            7p21.3  {'chr': '7', 'end': 10940153, 'ensemblgene': '...
# ...             ...                                                ...
# 621501       2q24.3  {'chr': '2', 'end': 166611482, 'ensemblgene': ...
# 621502       2q24.3  {'chr': '2', 'end': 166611482, 'ensemblgene': ...
# 621503       2q24.3  {'chr': '2', 'end': 166611482, 'ensemblgene': ...
# 621504       2q24.3  {'chr': '2', 'end': 166611482, 'ensemblgene': ...
# 621505       2q24.3  {'chr': '2', 'end': 166611482, 'ensemblgene': ...
#
#         entrezgene   HGNC                                            summary
# 0             4697   7687  The protein encoded by this gene belongs to th...
# 1             4697   7687  The protein encoded by this gene belongs to th...
# 2             4697   7687  The protein encoded by this gene belongs to th...
# 3             4697   7687  The protein encoded by this gene belongs to th...
# 4             4697   7687  The protein encoded by this gene belongs to th...
# ...            ...    ...                                                ...
# 621501        6332  10594  This gene encodes one of the many voltage-gate...
# 621502        6332  10594  This gene encodes one of the many voltage-gate...
# 621503        6332  10594  This gene encodes one of the many voltage-gate...
# 621504        6332  10594  This gene encodes one of the many voltage-gate...
# 621505        6332  10594  This gene encodes one of the many voltage-gate...
#
# [621506 rows x 34 columns]

# %%
# Count the number of rows in filtered_results_annotated_pd
num_rows = filtered_results_annotated_pd.shape[0]

# Print the number of rows
print(f"Number of rows in filtered_results_annotated_pd: {num_rows}")
# Out:
# Number of rows in filtered_results_annotated_pd: 621506

# %%
# Display the headers of the DataFrame
print(filtered_results_annotated_pd.columns)
# Out:
# Index(['EnsemblID', 'VariantID', 'tss_distance', 'CAF_eQTL', 'ma_samples',
#        'ma_count', 'pval_nominal', 'Beta', 'SE', 'chromosome', 'position',
#        'OtherAlleleA', 'CodedAlleleB', 'CAF', 'AltID', 'Source',
#        'AverageMaximumPosteriorCall', 'Info', 'AA_N', 'AB_N', 'BB_N', 'TotalN',
#        'MAF', 'MissingDataProportion', 'HWE_P', 'symbol', 'name', 'alias',
#        'type_of_gene', 'map_location', 'genomic_pos', 'entrezgene', 'HGNC',
#        'summary'],
#       dtype='object')

# %% [markdown]
# ## Saving
#  Let's save the annotated table.

# %%
# Specify the order of columns if needed
columns_order = ['EnsemblID', 'symbol', 
'VariantID', 'tss_distance', 'CAF_eQTL', 'ma_samples',
'ma_count', 'pval_nominal', 'Beta', 'SE', 'chromosome', 'position',
'OtherAlleleA', 'CodedAlleleB', 'CAF', 'AltID', 'Source',
'AverageMaximumPosteriorCall', 'Info', 'AA_N', 'AB_N', 'BB_N', 'TotalN',
'MAF', 'MissingDataProportion', 'HWE_P', 
'name', 'alias', 'type_of_gene', 'map_location', 'genomic_pos', 'entrezgene', 'HGNC', 'summary']
# Ensure these columns exist in your DataFrame

# Save the DataFrame with specified columns
filtered_results_annotated_pd.to_csv(
    os.path.join(
        molQTL_loc, 'target_regions.nom_cis_eqtl_annotated.txt.gz'),
    sep='\t',
    index=False,
    compression='gzip',
    columns=columns_order
)
